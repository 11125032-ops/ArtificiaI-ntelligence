# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/MyDrive/Mask')
# !ls  # 這行會顯示資料夾內容，確認檔案都在
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
# %cd /content/drive/MyDrive
# !git clone https://github.com/ultralytics/yolov5  # 下載 YOLOv5 原始碼
# %cd yolov5

import torch
from IPython.display import Image, clear_output

clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else'CPU'))
# Out:
# Setup complete. Using torch 2.9.0+cu126 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15095MB, multi_processor_count=40, uuid=4ab6d5d8-07fe-447a-1d24-b8d14941664c, pci_bus_id=0, pci_device_id=4, pci_domain_id=0, L2_cache_size=4MB)

# %%
# %pip install -qr requirements.txt

# %%
import yaml

yaml_path = '/content/drive/MyDrive/Mask/data.yaml'

with open(yaml_path, 'r') as f:
    data = yaml.safe_load(f)

# 強制修正為您雲端硬碟的絕對路徑
data['path'] = '/content/drive/MyDrive/Mask'
data['train'] = 'train/images'
data['val'] = 'valid/images'
data['test'] = 'test/images'

with open(yaml_path, 'w') as f:
    yaml.dump(data, f)

print("✅ data.yaml 路徑已修正完畢！")
# Out:
# ✅ data.yaml 路徑已修正完畢！

# %%
# %cd /content/drive/MyDrive/yolov5
# 開始訓練 (設定 300 輪)
# !python train.py --img 640 --batch 16 --epochs 300 --data /content/drive/MyDrive/Mask/data.yaml --weights yolov5s.pt --cache
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#      27/299      4.18G    0.05231    0.05654    0.01831        268        640:  71% 5/7 [00:01<00:00,  4.55it/s]/content/drive/MyDrive/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#      27/299      4.18G    0.05155    0.05561    0.01766        182        640:  86% 6/7 [00:01<00:00,  4.53it/s]/content/drive/MyDrive/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#      27/299      4.18G    0.05069    0.05786    0.01722        122        640: 100% 7/7 [00:01<00:00,  4.65it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.00it/s]
#                    all         29        162      0.259       0.59      0.468      0.228
#
# ...

# %%
# !python detect.py --weights runs/train/exp2/weights/best.pt --img 640 --conf 0.5 --source mask.jpg
# Out:
# detect: weights=['runs/train/exp2/weights/best.pt'], source=mask.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-450-g781b9d57 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/yolov5/mask.jpg: 288x640 7 masks, 2 no-masks, 33.6ms
# Speed: 0.4ms pre-process, 33.6ms inference, 69.9ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3
